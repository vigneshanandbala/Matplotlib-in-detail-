# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from numpy.random import randn, randint, uniform, sample

# %%
df = pd.DataFrame(randn(1000), index = pd.date_range('2019-06-07', periods = 1000), columns=['value'])
ts = pd.Series(randn(1000), index = pd.date_range('2019-06-07', periods = 1000))

# %%
df
# Out:
#                value
# 2019-06-07  0.178116
# 2019-06-08 -2.073116
# 2019-06-09 -0.664206
# 2019-06-10  0.013080
# 2019-06-11  0.757836
# ...              ...
# 2022-02-26 -1.602301
# 2022-02-27  2.038293
# 2022-02-28 -1.136273
# 2022-03-01 -0.578472
# 2022-03-02  0.639161
#
# [1000 rows x 1 columns]

# %%
df.head()
# Out:
#                value
# 2019-06-07  0.178116
# 2019-06-08 -2.073116
# 2019-06-09 -0.664206
# 2019-06-10  0.013080
# 2019-06-11  0.757836

# %%
ts
# Out:
# 2019-06-07   -2.205657
# 2019-06-08    0.298733
# 2019-06-09    1.338080
# 2019-06-10   -0.885277
# 2019-06-11   -0.581608
#                 ...
# 2022-02-26    1.520177
# 2022-02-27   -0.537612
# 2022-02-28    1.479703
# 2022-03-01    0.815631
# 2022-03-02    0.169259
# Freq: D, Length: 1000, dtype: float64

# %%
ts.head()
# Out:
# 2019-06-07   -2.205657
# 2019-06-08    0.298733
# 2019-06-09    1.338080
# 2019-06-10   -0.885277
# 2019-06-11   -0.581608
# Freq: D, dtype: float64

# %%
df.plot()

# %%
#Figsize is a size of the window

# %%
df.plot(figsize=(5,5))

# %%
df.plot(figsize=(15,5))

# %%
ts.plot()

# %%
ts.plot(figsize=(5,5))

# %%
ts.plot(figsize=(15,5))

# %%
plt.plot(df)

# %%
plt.plot(ts)

# %%
df['value'] = df['value'].cumsum()
a=df.head()
a
# Out:
#                 value
# 2019-06-07   0.178116
# 2019-06-08  -1.538767
# 2019-06-09  -5.814856
# 2019-06-10 -12.637070
# 2019-06-11 -21.247574

# %%
ts = ts.cumsum()
b=ts.head()
b
# Out:
# 2019-06-07    -2.205657
# 2019-06-08    -6.318240
# 2019-06-09   -10.999667
# 2019-06-10   -17.135216
# 2019-06-11   -25.306496
# Freq: D, dtype: float64

# %%
plt.plot(a)

# %%
plt.plot(b)

# %%
type(df), type(ts)
# Out:
# (pandas.core.frame.DataFrame, pandas.core.series.Series)

# %%
a.plot(figsize=(5,5))

# %%
b.plot(figsize=(5,5))

# %%
iris = sns.load_dataset('iris')
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
ax = iris.plot(figsize=(15,8), title='Iris Dataset')
ax
ax.set_xlabel('X Axis')
ax.set_ylabel('Y Axis')
# Out:
# Text(0, 0.5, 'Y Axis')

# %%
df.plot(kind="bar")

# %%
ts.plot(kind = 'bar')

# %%
df = iris.drop(['species'], axis = 1)

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
df.iloc[0]
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
df.iloc[0].plot(kind='bar')

# %%
df.iloc[0].plot.bar()

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic['pclass'].plot(kind = 'bar')

# %%
df = pd.DataFrame(randn(10, 4), columns=['a', 'b', 'c', 'd'])
df.head(10)
# Out:
#           a         b         c         d
# 0 -0.496717 -0.838343 -0.471864  0.366834
# 1  0.810029 -0.185155 -0.010131  2.157939
# 2 -0.476416  0.344266 -0.529880  1.013896
# 3 -0.461605 -1.578007  1.884853 -1.115060
# 4 -1.358559 -0.113771 -1.994602 -0.495543
# 5 -1.128654 -0.787666  1.640386 -1.249639
# 6 -1.570792  0.134956  1.140984 -0.309139
# 7  0.907622  0.270861 -0.610061  0.355774
# 8  0.207823 -0.148904 -0.210224  1.513638
# 9 -0.425297  0.379094  0.448964  0.181791

# %%
df.plot.bar()

# %%
df.plot(kind = 'bar')

# %%
df.plot.barh()

# %%
iris.plot.hist()

# %%
iris.plot(kind = 'hist')

# %%
iris.plot(kind = 'hist', stacked = False, bins = 50)

# %%
iris.plot(kind = 'hist', stacked = True, bins = 50, orientation = 'horizontal')

# %%
# importing pandas as pd
import pandas as pd
  
# Creating the dataframe
df = pd.DataFrame({"A":[5, 3, 6, 4],
                   "B":[11, 2, 4, 3], 
                   "C":[4, 3, 8, 5],
                   "D":[5, 4, 2, 8]})
  
# Print the dataframe
df
# Out:
#    A   B  C  D
# 0  5  11  4  5
# 1  3   2  3  4
# 2  6   4  8  2
# 3  4   3  5  8

# %%
df.diff(axis = 0)
# Out:
#      A    B    C    D
# 0  NaN  NaN  NaN  NaN
# 1 -2.0 -9.0 -1.0 -1.0
# 2  3.0  2.0  5.0 -2.0
# 3 -2.0 -1.0 -3.0  6.0

# %%
# To find the discrete difference
df.diff(axis = 0, periods = 1)
# Out:
#      A    B    C    D
# 0  NaN  NaN  NaN  NaN
# 1 -2.0 -9.0 -1.0 -1.0
# 2  3.0  2.0  5.0 -2.0
# 3 -2.0 -1.0 -3.0  6.0

# %%
iris['sepal_width'].diff()
# Out:
# 0      NaN
# 1     -0.5
# 2      0.2
# 3     -0.1
# 4      0.5
#       ...
# 145   -0.3
# 146   -0.5
# 147    0.5
# 148    0.4
# 149   -0.4
# Name: sepal_width, Length: 150, dtype: float64

# %%
iris['sepal_width'].diff().plot(kind = 'hist', stacked = True, bins = 50)

# %%
df = iris.drop(['species'], axis = 1)
df.diff().head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           NaN          NaN           NaN          NaN
# 1          -0.2         -0.5           0.0          0.0
# 2          -0.2          0.2          -0.1          0.0
# 3          -0.1         -0.1           0.2          0.0
# 4           0.4          0.5          -0.1          0.0

# %%
df.diff().hist(color = 'r', alpha = 0.5, figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000024E17FDC8C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024E1804EA08>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000024E1807E208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024E18293B88>]],
#       dtype=object)

# %%
color = {'boxes': 'DarkGreen', 'whiskers': 'b'}
color
# Out:
# {'boxes': 'DarkGreen', 'whiskers': 'b'}

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length')

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length', c = 'sepal_width')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length', label = 'Length')

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length', c = 'sepal_width', s = 190)

# %%
df.plot.hexbin(x = 'sepal_length', y = 'petal_length', gridsize = 5, C = 'sepal_width')

# %%
d = df.iloc[0]
d
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
d.plot.pie(figsize = (10,10))

# %%
d = df.head(3).T

# %%
d
# Out:
#                 0    1    2
# sepal_length  5.1  4.9  4.7
# sepal_width   3.5  3.0  3.2
# petal_length  1.4  1.4  1.3
# petal_width   0.2  0.2  0.2

# %%
d.plot.pie(subplots = True, figsize = (20, 20))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000024E18D78288>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000024E18DA8BC8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000024E18D78DC8>],
#       dtype=object)

# %%
d.plot.pie(subplots = True, figsize = (20, 20), fontsize = 26, autopct = '%.2f')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000024E19119B08>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000024E193154C8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000024E19119848>],
#       dtype=object)

# %%
d.plot.pie(subplots = True, figsize = (20, 20), fontsize = 26, autopct = '%.5f')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000024E19409508>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000024E19435F88>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000024E19410488>],
#       dtype=object)

# %%
[0.1]*4
# Out:
# [0.1, 0.1, 0.1, 0.1]

# %%
series = pd.Series([0.2]*5, index = ['a','b','c', 'd','e'], name = 'Pie Plot')
series
# Out:
# a    0.2
# b    0.2
# c    0.2
# d    0.2
# e    0.2
# Name: Pie Plot, dtype: float64

# %%
series = pd.Series([0.2]*5, index = ['a','b','c', 'd','e'], name = 'Pie Plot')
series.plot.pie()

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(df, figsize= (8,8), diagonal='kde', color = 'b')
plt.show()

# %%
ts.plot.kde()

# %%
ts.plot(style = 'r--', label = 'Series', legend = True)

# %%
ts.plot(style = 'r--', label = 'Series')

# %%
df.plot(legend = True, figsize = (10, 5), logy = True)

# %%
df.plot(legend = True, figsize = (10, 5))

# %%
x = df.drop(['sepal_width', 'petal_width'], axis = 1)
x.head()
# Out:
#    sepal_length  petal_length
# 0           5.1           1.4
# 1           4.9           1.4
# 2           4.7           1.3
# 3           4.6           1.5
# 4           5.0           1.4

# %%
y = df.drop(['sepal_length', 'petal_length'], axis = 1)
y.head()
# Out:
#    sepal_width  petal_width
# 0          3.5          0.2
# 1          3.0          0.2
# 2          3.2          0.2
# 3          3.1          0.2
# 4          3.6          0.2

# %%
ax = x.plot()
y.plot(figsize = (16,10), secondary_y=True,ax=ax)

# %%
x.plot(figsize=(10,5))

# %%
df.plot(subplots = True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000024E1B0974C8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000024E1B449BC8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000024E1B418D88>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000024E1B6E6E88>],
#       dtype=object)

# %%
df.plot(subplots = True, sharex = True, layout = (2,3), figsize = (16,8))
plt.tight_layout()

# %%
df.plot(subplots = True, sharex = False, layout = (2,3), figsize = (16,8))
plt.tight_layout()
